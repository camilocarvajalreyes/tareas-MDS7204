# %% [markdown]
# # Spectral Mixture Kernel

# %%
import numpy as np
np.random.seed(0)
from plot import plot_posterior
from gp.gp_lite_tarea import GaussianProcess
from gp.kernels import PeriodicKernel
from eval import eval

# Parámetros del código

np.random.seed(0)

# heart rates
hr1 = np.loadtxt('../../unidad_1/tarea_2/hr.7257.txt')

# eliminando parte de las observaciones
ALPHA = .3
indices = np.random.choice(len(hr1), int(len(hr1)*(1-ALPHA)), replace=False)
time = np.linspace(0,15,1800)
test_ind = np.array([i for i in range(len(hr1)) if i not in indices])

# %%
def test_params_SM(sigma = 1.0, length_scale=1.0,periodicity=1.0,sigma_n=1):
    gp = GaussianProcess(PeriodicKernel(sigma,length_scale,periodicity),sigma_n)
    gp.kernel.show_hypers()
    print(f'\tsigma_n = {gp.sigma_n}')

    gp.load(time[indices],hr1[indices])

    gp.compute_posterior(where=time)

    eval(test_ind,hr1[test_ind],gp,nombre_modelo='modelo sin entrenar')
    titulo = "Posterior para GP sin entrenar, alpha={}%".format(ALPHA*100)
    plot_posterior(gp,0, test_points=hr1[test_ind], test_times=time[test_ind],title=titulo)

# %% [markdown]
# **Por defecto**

# %%
test_params_SM(sigma = 1.0, length_scale=1.0, periodicity=1.0, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 27309.081194408227
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 14435.340681111244
# Error cuadratico medio conjunto train modelo sin entrenar: 25.55646809286183
# Error cuadratico medio conjunto test modelo sin entrenar: 31.944371517502763

# %% [markdown]
# **Variando length_scale**

# %%
test_params_SM(sigma = 1.0, length_scale=0.1, periodicity=1.0, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 0.1
# 	periodicidad = 1.0
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 131804.52033932565
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 14435.340681111244
# Error cuadratico medio conjunto train modelo sin entrenar: 28.686064064613426
# Error cuadratico medio conjunto test modelo sin entrenar: 35.51611286403196

# %%
test_params_SM(sigma = 1.0, length_scale=2.0, periodicity=1.0, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 2.0
# 	periodicidad = 1.0
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 23288.377543896982
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 14435.340681111244
# Error cuadratico medio conjunto train modelo sin entrenar: 25.68094071166699
# Error cuadratico medio conjunto test modelo sin entrenar: 31.941357482151155

# %% [markdown]
# **Variando periodicity**

# %%
test_params_SM(sigma = 1.0, length_scale=1.0, periodicity=0.1, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	periodicidad = 0.1
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 31633.04213049314
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 14435.340681111244
# Error cuadratico medio conjunto train modelo sin entrenar: 32.46973774976584
# Error cuadratico medio conjunto test modelo sin entrenar: 31.997864462774398

# %%
test_params_SM(sigma = 1.0, length_scale=1.0, periodicity=2.0, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	periodicidad = 2.0
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 27322.276797379578
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 17952.167388830072
# Error cuadratico medio conjunto train modelo sin entrenar: 25.479302383590433
# Error cuadratico medio conjunto test modelo sin entrenar: 32.4523368846366

# %%
test_params_SM(sigma = 1.0, length_scale=1.0, periodicity=5.0, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	periodicidad = 5.0
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 30388.415806071196
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 19642.10419903342
# Error cuadratico medio conjunto train modelo sin entrenar: 29.749740988017827
# Error cuadratico medio conjunto test modelo sin entrenar: 32.548217141994854

# %%
test_params_SM(sigma = 1.0, length_scale=1.0, periodicity=10, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	periodicidad = 10
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 30961.451764945232
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 19639.874895588044
# Error cuadratico medio conjunto train modelo sin entrenar: 31.307023192747423
# Error cuadratico medio conjunto test modelo sin entrenar: 32.80277211087852

# %% [markdown]
# **Variando sigma**

# %%
test_params_SM(sigma = 0.1, length_scale=1.0, periodicity=1.0, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 0.1
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 875630.4261631072
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 402952.0891238213
# Error cuadratico medio conjunto train modelo sin entrenar: 224.1888998049219
# Error cuadratico medio conjunto test modelo sin entrenar: 222.29517478465095

# %%
test_params_SM(sigma = 10.0, length_scale=1.0, periodicity=1.0, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 10.0
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 17347.371324899876
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 9833.051188099249
# Error cuadratico medio conjunto train modelo sin entrenar: 25.457359650768428
# Error cuadratico medio conjunto test modelo sin entrenar: 32.007979486929955

# %%
test_params_SM(sigma = 100000.0, length_scale=1.0, periodicity=1.0, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 100000.0
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 17360.22240873506
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 9795.732533187234
# Error cuadratico medio conjunto train modelo sin entrenar: 25.38144463791862
# Error cuadratico medio conjunto test modelo sin entrenar: 32.125255788492154

# %%
test_params_SM(sigma = 200000.0, length_scale=1.0, periodicity=1.0, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 200000.0
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 17373.933557162934
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 9796.323212968156
# Error cuadratico medio conjunto train modelo sin entrenar: 25.37171898552222
# Error cuadratico medio conjunto test modelo sin entrenar: 34.45579188337314

# %%
test_params_SM(sigma = 1000000.0, length_scale=1.0, periodicity=1.0, sigma_n=1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1000000.0
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 17387.777127829573
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 9800.729537189593
# Error cuadratico medio conjunto train modelo sin entrenar: 25.33517553310615
# Error cuadratico medio conjunto test modelo sin entrenar: 1573.3287605225462
