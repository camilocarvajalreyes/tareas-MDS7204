# %% [markdown]
# # Spectral Mixture Kernel

# %%
import numpy as np
np.random.seed(0)
from plot import plot_posterior
from gp.gp_lite_tarea import GaussianProcess
from gp.kernels import PeriodicKernel
from eval import eval

# Parámetros del código

np.random.seed(0)

# heart rates
hr1 = np.loadtxt('../../unidad_1/tarea_2/hr.7257.txt')

# eliminando parte de las observaciones
ALPHA = .3
indices = np.random.choice(len(hr1), int(len(hr1)*(1-ALPHA)), replace=False)
time = np.linspace(0,15,1800)
test_ind = np.array([i for i in range(len(hr1)) if i not in indices])

# %%
def test_params_SM(sigma = 1.0, length_scale=1.0,periodicity=1.0,sigma_n=0.1):
    gp = GaussianProcess(PeriodicKernel(sigma,length_scale,periodicity),sigma_n)
    gp.kernel.show_hypers()
    print(f'\tsigma_n = {gp.sigma_n}')

    gp.load(time[indices],hr1[indices])

    gp.compute_posterior(where=time)

    eval(test_ind,hr1[test_ind],gp,nombre_modelo='modelo sin entrenar')
    titulo = "Posterior para GP sin entrenar, alpha={}%".format(ALPHA*100)
    plot_posterior(gp,0, test_points=hr1[test_ind], test_times=time[test_ind],title=titulo)

# %% [markdown]
# **Por defecto**

# %%
test_params_SM(sigma = 1.0, length_scale=1.0, periodicity=1.0, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1611701.7653628592
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 866041.1024333624
# Error cuadratico medio conjunto train modelo sin entrenar: 25.457378861094277
# Error cuadratico medio conjunto test modelo sin entrenar: 32.00800202110355

# %% [markdown]
# **Variando length_scale**

# %%
test_params_SM(sigma = 1.0, length_scale=0.1, periodicity=1.0, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 0.1
# 	periodicidad = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1688734.3954529848
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 866041.1024333624
# Error cuadratico medio conjunto train modelo sin entrenar: 24.969446417708724
# Error cuadratico medio conjunto test modelo sin entrenar: 32.009101451990865

# %%
test_params_SM(sigma = 1.0, length_scale=2.0, periodicity=1.0, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 2.0
# 	periodicidad = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1613401.2764781164
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 866041.1024333624
# Error cuadratico medio conjunto train modelo sin entrenar: 25.53690223561676
# Error cuadratico medio conjunto test modelo sin entrenar: 31.98303437751629

# %% [markdown]
# **Variando periodicity**

# %%
test_params_SM(sigma = 1.0, length_scale=1.0, periodicity=0.1, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	periodicidad = 0.1
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 2048970.3878674651
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 866041.1024333624
# Error cuadratico medio conjunto train modelo sin entrenar: 32.41483815719336
# Error cuadratico medio conjunto test modelo sin entrenar: 31.93855093642944

# %%
test_params_SM(sigma = 1.0, length_scale=1.0, periodicity=2.0, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	periodicidad = 2.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1586501.4485391418
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 867822.2545156453
# Error cuadratico medio conjunto train modelo sin entrenar: 25.01727237178818
# Error cuadratico medio conjunto test modelo sin entrenar: 32.535302403511224

# %%
test_params_SM(sigma = 1.0, length_scale=1.0, periodicity=5.0, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	periodicidad = 5.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1536743.6555768293
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 860597.7274617191
# Error cuadratico medio conjunto train modelo sin entrenar: 23.496073308597644
# Error cuadratico medio conjunto test modelo sin entrenar: 32.75514477879326

# %%
test_params_SM(sigma = 1.0, length_scale=1.0, periodicity=10, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	periodicidad = 10
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1961792.121679569
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 856361.9655900493
# Error cuadratico medio conjunto train modelo sin entrenar: 30.967252922483784
# Error cuadratico medio conjunto test modelo sin entrenar: 33.08060129983863

# %% [markdown]
# **Variando sigma**

# %%
test_params_SM(sigma = 0.1, length_scale=1.0, periodicity=1.0, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 0.1
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 2610173.6491371705
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 1326497.0659388993
# Error cuadratico medio conjunto train modelo sin entrenar: 25.55654860024405
# Error cuadratico medio conjunto test modelo sin entrenar: 31.944333653562502

# %%
test_params_SM(sigma = 10.0, length_scale=1.0, periodicity=1.0, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 10.0
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1597659.6762254082
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 861430.2876795699
# Error cuadratico medio conjunto train modelo sin entrenar: 25.404031441721038
# Error cuadratico medio conjunto test modelo sin entrenar: 31.97208737670405

# %%
test_params_SM(sigma = 100000.0, length_scale=1.0, periodicity=1.0, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 100000.0
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1592460.8839903122
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 861058.6213532976
# Error cuadratico medio conjunto train modelo sin entrenar: 25.33091525997867
# Error cuadratico medio conjunto test modelo sin entrenar: 1569.7269358871292

# %%
test_params_SM(sigma = 200000.0, length_scale=1.0, periodicity=1.0, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 200000.0
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1632105.6476621907
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 861494.7093557294
# Error cuadratico medio conjunto train modelo sin entrenar: 28.30624396750595
# Error cuadratico medio conjunto test modelo sin entrenar: 36557.23975604916

# %%
test_params_SM(sigma = 1000000.0, length_scale=1.0, periodicity=1.0, sigma_n=0.1)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1000000.0
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 393006.7296040387
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 844924.2346987355
# Error cuadratico medio conjunto train modelo sin entrenar: 2570.9771912008887
# Error cuadratico medio conjunto test modelo sin entrenar: 232990792.90213326

# %% [markdown]
# **Más**

# %%
test_params_SM(sigma = 1500000.1, length_scale=1.0, periodicity=1.0, sigma_n=1.0)
# Out:
# Hyperparámetros Kernel Periodico:
# 	sigma = 1500000.1
# 	largo de escala = 1.0
# 	periodicidad = 1.0
# 	sigma_n = 1.0
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 17464.614058695664
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 9800.13673560935
# Error cuadratico medio conjunto train modelo sin entrenar: 25.86329659523412
# Error cuadratico medio conjunto test modelo sin entrenar: 8426.496321674167
