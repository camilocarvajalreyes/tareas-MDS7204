# %% [markdown]
# # Spectral Mixture Kernel

# %%
import numpy as np
np.random.seed(0)
from plot import plot_posterior
from gp.gp_lite_tarea import GaussianProcess
from gp.kernels import SpectralMixtureKernel, PeriodicKernel
from eval import eval

# Parámetros del código

np.random.seed(0)

# heart rates
hr1 = np.loadtxt('../../unidad_1/tarea_2/hr.7257.txt')

# eliminando parte de las observaciones
ALPHA = .3
indices = np.random.choice(len(hr1), int(len(hr1)*(1-ALPHA)), replace=False)
time = np.linspace(0,15,1800)
test_ind = np.array([i for i in range(len(hr1)) if i not in indices])

# %%
def test_params_SM(sigma,gamma,mu,sigma_n):
    gp = GaussianProcess(SpectralMixtureKernel(sigma,gamma,mu),sigma_n)
    gp.kernel.show_hypers()
    print(f'\tsigma_n = {gp.sigma_n}')

    gp.load(time[indices],hr1[indices])
    # plot_data(gp)

    gp.compute_posterior(where=time)

    eval(test_ind,hr1[test_ind],gp,nombre_modelo='modelo sin entrenar')
    titulo = "Posterior para GP sin entrenar, alpha={}%".format(ALPHA*100)
    plot_posterior(gp,0, test_points=hr1[test_ind], test_times=time[test_ind],title=titulo)

# %% [markdown]
# **Por defecto**

# %%
test_params_SM(sigma = 10, gamma = 0.5, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1331693.8924771405
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 21326.59253149378
# Error cuadratico medio conjunto train modelo sin entrenar: 19.2968054197779
# Error cuadratico medio conjunto test modelo sin entrenar: 9289.688342168309

# %% [markdown]
# **Variando sigma**

# %%
test_params_SM(sigma = 50, gamma = 0.5, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 50
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1004904.2379183976
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 3987.770097086626
# Error cuadratico medio conjunto train modelo sin entrenar: 14.281301170578176
# Error cuadratico medio conjunto test modelo sin entrenar: 9289.526207446084

# %%
test_params_SM(sigma = 1, gamma = 0.5, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 1
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1740155.0401189073
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 1881923.213857403
# Error cuadratico medio conjunto train modelo sin entrenar: 26.51464555759981
# Error cuadratico medio conjunto test modelo sin entrenar: 9289.433683855275

# %%
test_params_SM(sigma = 0.2, gamma = 0.5, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 0.2
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 2614801.328303159
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 39352386.80321013
# Error cuadratico medio conjunto train modelo sin entrenar: 28.485577905129926
# Error cuadratico medio conjunto test modelo sin entrenar: 9289.372696082404

# %% [markdown]
# **Variando gamma**

# %%
test_params_SM(sigma = 10, gamma = 0.1, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.1
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1841989.344702459
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 14785.096804333789
# Error cuadratico medio conjunto train modelo sin entrenar: 29.21150693295065
# Error cuadratico medio conjunto test modelo sin entrenar: 9280.948692754053

# %%
test_params_SM(sigma = 5, gamma = 1.0, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 5
# 	gamma = 1.0
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 450617.98251395737
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 87333.88170068516
# Error cuadratico medio conjunto train modelo sin entrenar: 5.472524392819519
# Error cuadratico medio conjunto test modelo sin entrenar: 9289.514057364664

# %%
test_params_SM(sigma = 5, gamma = 10.0, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 5
# 	gamma = 10.0
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 102191.2670055643
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 102980.5817680553
# Error cuadratico medio conjunto train modelo sin entrenar: 1.4582215148238309
# Error cuadratico medio conjunto test modelo sin entrenar: 9289.517057207227

# %%
test_params_SM(sigma = 5, gamma = 1000, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 5
# 	gamma = 1000
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 55883.99510723429
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 102983.29033446714
# Error cuadratico medio conjunto train modelo sin entrenar: 0.057056137056919976
# Error cuadratico medio conjunto test modelo sin entrenar: 9289.519696090874

# %% [markdown]
# **Variando mu**

# %%
test_params_SM(sigma = 5, gamma = 0.5, mu = 10, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 5
# 	gamma = 0.5
# 	mu = 10
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 582759868.7066454
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 77832.79960631717
# Error cuadratico medio conjunto train modelo sin entrenar: 9251.847115348659
# Error cuadratico medio conjunto test modelo sin entrenar: 9359.047320969992

# %%
test_params_SM(sigma = 5, gamma = 0.5, mu = 1, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 5
# 	gamma = 0.5
# 	mu = 1
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 492627587.4537259
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 77832.79960631717
# Error cuadratico medio conjunto train modelo sin entrenar: 7527.803294491585
# Error cuadratico medio conjunto test modelo sin entrenar: 9363.002252034232

# %%
test_params_SM(sigma = 5, gamma = 0.5, mu = 0.75, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 5
# 	gamma = 0.5
# 	mu = 0.75
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 34728451.076736435
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 112886.687531289
# Error cuadratico medio conjunto train modelo sin entrenar: 48.21733772818321
# Error cuadratico medio conjunto test modelo sin entrenar: 9290.939322962824

# %% [markdown]
# **Variando Sigma_n**

# %%
test_params_SM(sigma = 5, gamma = 0.5, mu = 0, sigma_n = 0)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 5
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 702443054.6914756
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 77858.53080782907
# Error cuadratico medio conjunto train modelo sin entrenar: 9.196271287221393
# Error cuadratico medio conjunto test modelo sin entrenar: 9289.49412153546

# %%
test_params_SM(sigma = 5, gamma = 0.5, mu = 0, sigma_n = 0.5)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 5
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0.5
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 70097.99340454923
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 77222.27728009426
# Error cuadratico medio conjunto train modelo sin entrenar: 26.513892897108676
# Error cuadratico medio conjunto test modelo sin entrenar: 9289.433708277522

# %%
test_params_SM(sigma = 5, gamma = 0.5, mu = 0, sigma_n = 10)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 5
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 10
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 5491.281126113975
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 21098.414071959975
# Error cuadratico medio conjunto train modelo sin entrenar: 36.00329595015419
# Error cuadratico medio conjunto test modelo sin entrenar: 9289.40085864225
