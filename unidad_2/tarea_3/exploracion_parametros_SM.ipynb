# %% [markdown]
# # Spectral Mixture Kernel

# %%
import numpy as np
np.random.seed(0)
from plot import plot_posterior
from gp.gp_lite_tarea import GaussianProcess
from gp.kernels import SpectralMixtureKernel
from eval import eval

# Parámetros del código

np.random.seed(0)

# heart rates
hr1 = np.loadtxt('../../unidad_1/tarea_2/hr.7257.txt')

# eliminando parte de las observaciones
ALPHA = .3
indices = np.random.choice(len(hr1), int(len(hr1)*(1-ALPHA)), replace=False)
time = np.linspace(0,15,1800)
test_ind = np.array([i for i in range(len(hr1)) if i not in indices])

# %%
def test_params_SM(sigma,gamma,mu,sigma_n):
    gp = GaussianProcess(SpectralMixtureKernel(sigma,gamma,mu),sigma_n)
    gp.kernel.show_hypers()
    print(f'\tsigma_n = {gp.sigma_n}')

    gp.load(time[indices],hr1[indices])
    # plot_data(gp)

    gp.compute_posterior(where=time)

    eval(time[test_ind],hr1[test_ind],gp,nombre_modelo='modelo sin entrenar')
    titulo = "Posterior para GP sin entrenar, alpha={}%".format(ALPHA*100)
    plot_posterior(gp,0, test_points=hr1[test_ind], test_times=time[test_ind],title=titulo)

# %% [markdown]
# **Por defecto**

# %%
test_params_SM(sigma = 10, gamma = 0.5, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1331693.8924771405
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 500467.39386275737
# Error cuadratico medio conjunto train modelo sin entrenar: 19.2968054197779
# Error cuadratico medio conjunto test modelo sin entrenar: 19.39470040268562

# %% [markdown]
# **Variando sigma**

# %%
test_params_SM(sigma = 50, gamma = 0.5, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 50
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1004904.2379183976
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 368371.44179431605
# Error cuadratico medio conjunto train modelo sin entrenar: 14.281301170578176
# Error cuadratico medio conjunto test modelo sin entrenar: 14.413677856112193

# %%
test_params_SM(sigma = 1, gamma = 0.5, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 1
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1740155.0401189073
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 696848.8971025958
# Error cuadratico medio conjunto train modelo sin entrenar: 26.51464555759981
# Error cuadratico medio conjunto test modelo sin entrenar: 26.649029240165166

# %%
test_params_SM(sigma = 0.2, gamma = 0.5, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 0.2
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 2614801.328303159
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 755262.8614101531
# Error cuadratico medio conjunto train modelo sin entrenar: 28.485577905129926
# Error cuadratico medio conjunto test modelo sin entrenar: 28.734391289716168

# %% [markdown]
# **Variando gamma**

# %%
test_params_SM(sigma = 10, gamma = 0.1, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.1
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1841989.344702459
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 757185.9035084388
# Error cuadratico medio conjunto train modelo sin entrenar: 29.21150693295065
# Error cuadratico medio conjunto test modelo sin entrenar: 28.48591487458644

# %%
test_params_SM(sigma = 10, gamma = 1.0, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 1.0
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 347308.56421040057
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 142721.02019521396
# Error cuadratico medio conjunto train modelo sin entrenar: 4.819357623666953
# Error cuadratico medio conjunto test modelo sin entrenar: 5.480338943252272

# %%
test_params_SM(sigma = 10, gamma = 10.0, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 10.0
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 90015.03184441465
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 49233.92758971233
# Error cuadratico medio conjunto train modelo sin entrenar: 1.3398011185701764
# Error cuadratico medio conjunto test modelo sin entrenar: 2.0801386376359567

# %%
test_params_SM(sigma = 10, gamma = 1000, mu = 0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 1000
# 	mu = 0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 17608.438514347545
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 8055.1727046190235
# Error cuadratico medio conjunto train modelo sin entrenar: 0.040184692284053074
# Error cuadratico medio conjunto test modelo sin entrenar: 1.9420601567276528

# %% [markdown]
# **Variando mu**

# %%
test_params_SM(sigma = 10, gamma = 0.5, mu = 10, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.5
# 	mu = 10
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 582105908.5688021
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 259513173.6727349
# Error cuadratico medio conjunto train modelo sin entrenar: 9241.77870881695
# Error cuadratico medio conjunto test modelo sin entrenar: 10040.862047027536

# %%
test_params_SM(sigma = 10, gamma = 0.5, mu = 1, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.5
# 	mu = 1
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 460463728.89642686
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 186416876.15104285
# Error cuadratico medio conjunto train modelo sin entrenar: 6860.496153135458
# Error cuadratico medio conjunto test modelo sin entrenar: 7202.696403687356

# %%
test_params_SM(sigma = 10, gamma = 0.5, mu = 0.75, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.5
# 	mu = 0.75
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 9470684.055962954
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 202654.31872976702
# Error cuadratico medio conjunto train modelo sin entrenar: 7.921977414094253
# Error cuadratico medio conjunto test modelo sin entrenar: 9.063283968440174

# %% [markdown]
# **Escogiendo buena combinación de parámetros**

# %%
test_params_SM(sigma = 10, gamma = 0.75, mu = 0.75, sigma_n = 0.5)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.75
# 	mu = 0.75
# 	sigma_n = 0.5
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 411445.363469579
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 8292.289536299802
# Error cuadratico medio conjunto train modelo sin entrenar: 7.972920996631809
# Error cuadratico medio conjunto test modelo sin entrenar: 9.115489780314785

# %%
test_params_SM(sigma = 10, gamma = 10, mu = 0.75, sigma_n = 0.75)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 10
# 	mu = 0.75
# 	sigma_n = 0.75
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 4994.352625399497
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 1236.826481042979
# Error cuadratico medio conjunto train modelo sin entrenar: 1.3234283906387458
# Error cuadratico medio conjunto test modelo sin entrenar: 2.055591048973359

# %% [markdown]
# **Variando Sigma_n**

# %%
test_params_SM(sigma = 10, gamma = 0.5, mu = 0, sigma_n = 0)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 570482176.9445214
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 212007205.7606971
# Error cuadratico medio conjunto train modelo sin entrenar: 7.908376314923951
# Error cuadratico medio conjunto test modelo sin entrenar: 8.173507079104835

# %%
test_params_SM(sigma = 10, gamma = 0.5, mu = 0, sigma_n = 0.5)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 0.5
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 66453.17805709949
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 26461.36880969197
# Error cuadratico medio conjunto train modelo sin entrenar: 25.164046583796683
# Error cuadratico medio conjunto test modelo sin entrenar: 25.246083665297025

# %%
test_params_SM(sigma = 10, gamma = 0.5, mu = 0, sigma_n = 10)
# Out:
# Hyperparámetros Kernel SpectralMixture:
# 	sigma = 10
# 	gamma = 0.5
# 	mu = 0
# 	sigma_n = 10
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 4590.647518842234
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 1820.843229570974
# Error cuadratico medio conjunto train modelo sin entrenar: 29.802253245799985
# Error cuadratico medio conjunto test modelo sin entrenar: 29.73854622384522
