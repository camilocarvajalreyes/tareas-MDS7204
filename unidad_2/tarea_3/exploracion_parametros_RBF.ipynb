# %% [markdown]
# # Spectral Mixture Kernel

# %%
import numpy as np
np.random.seed(0)
from plot import plot_posterior
from gp.gp_lite_tarea import GaussianProcess
from gp.kernels import RBFKernel
from eval import eval

# Parámetros del código

np.random.seed(0)

# heart rates
hr1 = np.loadtxt('../../unidad_1/tarea_2/hr.7257.txt')

# eliminando parte de las observaciones
ALPHA = .3
indices = np.random.choice(len(hr1), int(len(hr1)*(1-ALPHA)), replace=False)
time = np.linspace(0,15,1800)
test_ind = np.array([i for i in range(len(hr1)) if i not in indices])

# %%
def test_params_SM(sigma = 1.0, length_scale = 1.0, sigma_n = 0.1):
    gp = GaussianProcess(RBFKernel(sigma,length_scale),sigma_n)
    gp.kernel.show_hypers()
    print(f'\tsigma_n = {gp.sigma_n}')

    gp.load(time[indices],hr1[indices])

    gp.compute_posterior(where=time)

    eval(time[test_ind],hr1[test_ind],gp,nombre_modelo='modelo sin entrenar')
    titulo = "Posterior para GP sin entrenar, alpha={}%".format(ALPHA*100)
    plot_posterior(gp,0, test_points=hr1[test_ind], test_times=time[test_ind],title=titulo)

# %% [markdown]
# **Por defecto**

# %%
test_params_SM(sigma = 1.0, length_scale = 1.0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1740155.0401189073
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 696848.8971025958
# Error cuadratico medio conjunto train modelo sin entrenar: 26.51464555759981
# Error cuadratico medio conjunto test modelo sin entrenar: 26.649029240165166

# %% [markdown]
# **Variando length_scale**

# %%
test_params_SM(sigma = 1.0, length_scale = 0.01, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 1.0
# 	largo de escala = 0.01
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 2665544.9088083366
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 136132.65272555678
# Error cuadratico medio conjunto train modelo sin entrenar: 0.29037346087690447
# Error cuadratico medio conjunto test modelo sin entrenar: 540.7536478740816

# %%
test_params_SM(sigma = 1.0, length_scale = 0.1, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 1.0
# 	largo de escala = 0.1
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 330608.9510774324
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 26715.973076440267
# Error cuadratico medio conjunto train modelo sin entrenar: 0.6860381091448526
# Error cuadratico medio conjunto test modelo sin entrenar: 1.238291669537993

# %%
test_params_SM(sigma = 1.0, length_scale = 0.5, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 1.0
# 	largo de escala = 0.5
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 381932.5343424524
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 141418.66846058087
# Error cuadratico medio conjunto train modelo sin entrenar: 4.658642032167596
# Error cuadratico medio conjunto test modelo sin entrenar: 5.481374808657041

# %%
test_params_SM(sigma = 1.0, length_scale = 2.0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 1.0
# 	largo de escala = 2.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1878575.8469967037
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 759109.7080785803
# Error cuadratico medio conjunto train modelo sin entrenar: 29.475295157872125
# Error cuadratico medio conjunto test modelo sin entrenar: 28.543157161112315

# %% [markdown]
# **Variando sigma**

# %%
test_params_SM(sigma = 0.1, length_scale = 1.0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 0.1
# 	largo de escala = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 5006623.812171129
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 781289.6340604664
# Error cuadratico medio conjunto train modelo sin entrenar: 29.803814168610288
# Error cuadratico medio conjunto test modelo sin entrenar: 29.739630303402045

# %%
test_params_SM(sigma = 0.5, length_scale = 1.0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 0.5
# 	largo de escala = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1887114.89452185
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 726146.9784690882
# Error cuadratico medio conjunto train modelo sin entrenar: 27.441424953047196
# Error cuadratico medio conjunto test modelo sin entrenar: 27.687907983754656

# %%
test_params_SM(sigma = 1.5, length_scale = 1.0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 1.5
# 	largo de escala = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1685886.8141634965
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 675396.9629667696
# Error cuadratico medio conjunto train modelo sin entrenar: 25.799344490402923
# Error cuadratico medio conjunto test modelo sin entrenar: 25.887576377251243

# %%
test_params_SM(sigma = 2.0, length_scale = 1.0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 2.0
# 	largo de escala = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1648715.2778284287
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 657034.8655732981
# Error cuadratico medio conjunto train modelo sin entrenar: 25.165220729017896
# Error cuadratico medio conjunto test modelo sin entrenar: 25.247251786284338

# %%
test_params_SM(sigma = 5.0, length_scale = 1.0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 5.0
# 	largo de escala = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1493255.686699315
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 570270.7915003403
# Error cuadratico medio conjunto train modelo sin entrenar: 22.04372863030655
# Error cuadratico medio conjunto test modelo sin entrenar: 22.143142941195684

# %%
test_params_SM(sigma = 50, length_scale = 1.0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 50
# 	largo de escala = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 1004904.2379183976
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 368371.44179431605
# Error cuadratico medio conjunto train modelo sin entrenar: 14.281301170578176
# Error cuadratico medio conjunto test modelo sin entrenar: 14.413677856112193

# %%
test_params_SM(sigma = 100, length_scale = 1.0, sigma_n = 0.1)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 100
# 	largo de escala = 1.0
# 	sigma_n = 0.1
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 825500.473496453
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 278387.3374168404
# Error cuadratico medio conjunto train modelo sin entrenar: 10.856245801280492
# Error cuadratico medio conjunto test modelo sin entrenar: 10.975830834604478

# %% [markdown]
# **Testeando sigma_n**

# %%
test_params_SM(sigma = 1.0, length_scale = 1.0, sigma_n = 0.5)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	sigma_n = 0.5
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 105056.11257897773
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 30393.98002144846
# Error cuadratico medio conjunto train modelo sin entrenar: 28.484965565800056
# Error cuadratico medio conjunto test modelo sin entrenar: 28.733855294737328

# %%
test_params_SM(sigma = 1.0, length_scale = 1.0, sigma_n = 0.75)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 1.0
# 	largo de escala = 1.0
# 	sigma_n = 0.75
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 65334.66776263329
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 14034.6330743919
# Error cuadratico medio conjunto train modelo sin entrenar: 29.106047439889256
# Error cuadratico medio conjunto test modelo sin entrenar: 29.238093779772903

# %% [markdown]
# **Best manual**

# %%
test_params_SM(sigma = 5.0, length_scale = 0.5, sigma_n = 0.25)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 5.0
# 	largo de escala = 0.5
# 	sigma_n = 0.25
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 49349.59940922966
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 21826.37767092155
# Error cuadratico medio conjunto train modelo sin entrenar: 4.4814544990412974
# Error cuadratico medio conjunto test modelo sin entrenar: 5.352148312090114

# %%
test_params_SM(sigma = 5.0, length_scale = 0.1, sigma_n = 0.5)
# Out:
# Hyperparámetros Kernel RBF:
# 	sigma = 5.0
# 	largo de escala = 0.1
# 	sigma_n = 0.5
# Log-verosimilitud negativa conjunto train modelo sin entrenar: 14048.255374619584
# Log-verosimilitud negativa conjunto test modelo sin entrenar: 1255.9675309397323
# Error cuadratico medio conjunto train modelo sin entrenar: 0.685982219213709
# Error cuadratico medio conjunto test modelo sin entrenar: 1.2382274578319008
